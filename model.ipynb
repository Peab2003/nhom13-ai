# %%
import os
import whisper
from pytube import YouTube
import datetime
import tempfile

# Tải mô hình Whisper
model = whisper.load_model('base')

def transcribe_video_to_text(file_path):
    # Kiểm tra sự tồn tại của tệp
    if not os.path.isfile(file_path):
        raise FileNotFoundError(f"The video {file_path} does not exist.")
    
    # Chuyển đổi âm thanh thành văn bản
    result = model.transcribe(file_path)
    
    # Tạo một chuỗi để lưu kết quả
    transcription = ""
    for indx, segment in enumerate(result['segments']):
        start_time = str(datetime.timedelta(seconds=int(segment['start'])))
        end_time = str(datetime.timedelta(seconds=int(segment['end'])))
        transcription += str(indx + 1) + '\n'
        transcription += start_time + ' --> ' + end_time + '\n'
        transcription += segment['text'] + '\n\n'
    
    return transcription

def download_youtube_audio_to_temp(youtube_link):
    yt = YouTube(youtube_link)
    stream = yt.streams.filter(only_audio=True).first()
    temp_file = tempfile.NamedTemporaryFile(delete=False, suffix='.mp4')
    stream.download(filename=temp_file.name)
    return temp_file.name

# Kết quả chuyển đổi sẽ được lưu vào đây
transcription = ""

# Sử dụng video cục bộ
video_path = 'video.mp4'
try:
    transcription += "Local video transcription:\n"
    transcription += transcribe_video_to_text(video_path)
except FileNotFoundError as e:
    transcription += str(e) + "\n"

# Sử dụng link YouTube
youtube_link = 'https://www.youtube.com/watch?v=_EvjyXDGM5w&list=RD713huzVp0dY&index=4'
try:
    temp_audio_file = download_youtube_audio_to_temp(youtube_link)
    transcription += "\nYouTube video transcription:\n"
    transcription += transcribe_video_to_text(temp_audio_file)
    os.remove(temp_audio_file)  # Xóa tệp tạm thời sau khi hoàn tất
except FileNotFoundError as e:
    transcription += str(e) + "\n"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 import whisper
#       3 from pytube import YouTube
#       4 import datetime
#
# ModuleNotFoundError: No module named 'whisper'

# %%
# In kết quả
print(transcription)
# Out:
# 1
# 0:00:00 --> 0:00:04
#  I got something like a funny feeling
#
# 2
# 0:00:04 --> 0:00:07
#  There's never a self-pulture still like mine
#
# 3
# 0:00:07 --> 0:00:11
#  Take it away, take it away
#
# 4
# 0:00:11 --> 0:00:14
#  Just take it away
#
# 5
# 0:00:14 --> 0:00:18
#  Look, I find it, tell me it's cleaning the nighttime
#
# 6
# 0:00:18 --> 0:00:21
#  I've never seen like my mind
#
# 7
# 0:00:21 --> 0:00:24
#  Don't take it away, take it away
#
# 8
# 0:00:24 --> 0:00:28
#  Don't take it away
#
# 9
# 0:00:29 --> 0:00:32
#  Wish I could say what I'd say, babe
#
# 10
# 0:00:32 --> 0:00:35
#  But for really is too late
#
# 11
# 0:00:35 --> 0:00:41
#  I'm not sometimes as hard to take a step away
#
# 12
# 0:00:41 --> 0:00:44
#  If I could gather some more to explain
#
# 13
# 0:00:44 --> 0:00:48
#  Some looks like light shines through your pain
#
# 14
# 0:00:48 --> 0:00:54
#  In motion, I'm not even new away
#
# 15
# 0:00:54 --> 0:00:57
#  But at the time, I didn't know
#
# 16
# 0:00:57 --> 0:01:01
#  When an ambulance thanks your show
#
# 17
# 0:01:01 --> 0:01:04
#  Straight from your heart, miles apart
#
# 18
# 0:01:04 --> 0:01:08
#  No words have far
#
# 19
# 0:01:08 --> 0:01:11
#  I got something like a funny feeling
#
# 20
# 0:01:11 --> 0:01:14
#  There's never a self-pulture still like mine
#
# 21
# 0:01:14 --> 0:01:17
#  Take it away, take it away
#
# 22
# 0:01:17 --> 0:01:21
#  Just take it away
#
# 23
# 0:01:21 --> 0:01:24
#  Look, I find it, tell me it's cleaning the nighttime
#
# 24
# 0:01:24 --> 0:01:29
#  But at the time, I'm not even taking it away
#
# 25
# 0:01:29 --> 0:01:33
#  Take it away, take it away
#
# 26
# 0:01:35 --> 0:01:38
#  I would have said I was fortunate
#
# 27
# 0:01:38 --> 0:01:41
#  Because there's nothing now with shame
#
# 28
# 0:01:41 --> 0:01:44
#  I was just waiting for my moment
#
# 29
# 0:01:44 --> 0:01:49
#  But it isn't vain
#
# 30
# 0:01:49 --> 0:01:51
#  Every piece that I've been painting
#
# 31
# 0:01:51 --> 0:01:54
#  Should I throw them all away
#
# 32
# 0:01:54 --> 0:02:00
#  Like I fade, I will face this, bring me pain
#
# 33
# 0:02:02 --> 0:02:06
#  I roll my paint to wire here
#
# 34
# 0:02:06 --> 0:02:10
#  But I know that they don't care
#
# 35
# 0:02:10 --> 0:02:15
#  But I know that you don't care
#
# 36
# 0:02:16 --> 0:02:21
#  I'm sorry for whatever I've been through
#
# 37
# 0:02:21 --> 0:02:23
#  It's uneasy, put it down
#
# 38
# 0:02:23 --> 0:02:28
#  I'll love your love on a campus page
#
# 39
# 0:02:28 --> 0:02:31
#  I got something like a funny feeling
#
# 40
# 0:02:31 --> 0:02:34
#  There's never a self-pulture still like mine
#
# 41
# 0:02:34 --> 0:02:37
#  Take it away, take it away
#
# 42
# 0:02:37 --> 0:02:41
#  Just take it away
#
# 43
# 0:02:41 --> 0:02:45
#  Look, I find it, tell me it's cleaning the nighttime
#
# 44
# 0:02:45 --> 0:02:49
#  But at the time, I'm not even taking it away
#
# 45
# 0:02:49 --> 0:02:54
#  Take it away, take it away
